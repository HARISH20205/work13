# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from seaborn import load_dataset

# %%
x=np.random.randn(100)
y=np.random.randn(100)
color=np.random.randn(100)
size=100*np.random.randn(100)
plt.scatter(x,y,c=color,s=size,alpha=0.9,cmap=plt.cm.viridis)
plt.colorbar()
# Out:
# c:\Users\haris\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
iris=load_dataset('iris')
plt.figure(figsize=(4,3))
clr=np.random.randn(len(iris.species))
clr[iris.species==iris.species.unique()[0]]=0.2
clr[iris.species==iris.species.unique()[1]]=0.4
clr[iris.species==iris.species.unique()[2]]=0.6

plt.scatter(iris.sepal_length,iris.sepal_width,c=clr,cmap=plt.cm.coolwarm)

# %%
#meshgrid -creates all possibilities of given sets

X,Y=np.meshgrid([1,2,3],[4,5,6])

X,Y
# Out:
# (array([[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]]),
#  array([[4, 4, 4],
#         [5, 5, 5],
#         [6, 6, 6]]))

# %%
plt.figure(figsize=(5,5),dpi=100)
X,Y=np.meshgrid(np.linspace(0,100,50),np.linspace(0,100,40))
Z=X+Y
plt.contour(X,Y,Z,100,cmap='RdGy')
plt.colorbar()

# %%
plt.figure(figsize=(4,3))
d1=np.random.normal(0,0.7,1000)
d2=np.random.normal(-5,2,1000)
d3=np.random.normal(5,3,1000)
plt.hist(d1,alpha=0.98,bins=100)
plt.hist(d2,alpha=0.98,bins=100)
plt.hist(d3,alpha=0.98,bins=100)
# Out:
# (array([ 1.,  0.,  1.,  0.,  0.,  0.,  1.,  1.,  2.,  1.,  0.,  0.,  2.,
#          5.,  2.,  2.,  2.,  2.,  2.,  2.,  4.,  4.,  3.,  4.,  5.,  7.,
#         10., 10.,  9.,  7., 10., 11., 10.,  8., 13.,  8., 19., 14., 11.,
#         22., 24., 14., 27., 13., 25., 22., 27., 18., 20., 25., 26., 26.,
#         29., 21., 23., 36., 22., 23., 28., 26., 16., 23., 19., 17., 18.,
#         14., 18., 12., 16., 11., 10., 15., 12., 11., 13., 16.,  8.,  9.,
#         10.,  6.,  3.,  6.,  3.,  2.,  1.,  4.,  4.,  3.,  0.,  2.,  1.,
#          0.,  3.,  0.,  2.,  0.,  0.,  0.,  0.,  2.]),
#  array([-4.58488239, -4.39935241, -4.21382243, -4.02829245, -3.84276247,
#         -3.65723249, -3.47170251, -3.28617253, -3.10064255, -2.91511257,
#         -2.72958259, -2.54405261, -2.35852263, -2.17299265, -1.98746267,
#         -1.80193269, -1.61640271, -1.43087273, -1.24534275, -1.05981277,
#         -0.87428279, -0.68875281, -0.50322283, -0.31769285, -0.13216287,
# ...

# %%
iris=load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(4,3))
parms=dict(histtype='stepfilled',alpha=0.4,bins=30)

plt.hist(iris.sepal_length,**parms)
plt.hist(iris.sepal_width,**parms)
plt.hist(iris.petal_length,**parms)
plt.hist(iris.petal_width,**parms)
# Out:
# (array([ 5., 29.,  7.,  7.,  0.,  1.,  1.,  0.,  0.,  0.,  0.,  7.,  3.,
#          5.,  0., 13.,  8., 12.,  4.,  2.,  0., 12.,  5.,  6.,  0.,  6.,
#          3.,  8.,  3.,  3.]),
#  array([0.1 , 0.18, 0.26, 0.34, 0.42, 0.5 , 0.58, 0.66, 0.74, 0.82, 0.9 ,
#         0.98, 1.06, 1.14, 1.22, 1.3 , 1.38, 1.46, 1.54, 1.62, 1.7 , 1.78,
#         1.86, 1.94, 2.02, 2.1 , 2.18, 2.26, 2.34, 2.42, 2.5 ]),
#  [<matplotlib.patches.Polygon at 0x1b09cc22090>])

# %%
fig,ax=plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].plot(np.random.rand(20),np.random.rand(20),'sr')
        ax[i,j].set(xticks=[],yticks=[])

# %%
fig,ax=plt.subplots(2,3,figsize=(4,3),sharex='col',sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].imshow(np.random.rand(200,200))
        ax[i,j].set(xticks=[],yticks=[])

# %%
from  sklearn.datasets import fetch_lfw_people

faces=fetch_lfw_people(min_faces_per_person=12)

# %%
for i in range(12):
    print(plt.imshow(faces.images[i]))
# Out:
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))
# AxesImage(shape=(62, 47))

# %%
fig,ax=plt.subplots(4,3,figsize=(4,3),sharex='col',sharey='row')
faces=fetch_lfw_people(min_faces_per_person=12)
k=0
for i in range(4):
    for j in range(3):
        ax[i,j].imshow(faces.images[k],plt.cm.bone)
        ax[i,j].set(xticks=[],yticks=[])
        k+=1

# %%
from mpl_toolkits.mplot3d import Axes3D

fig =plt.figure()

ax=fig.gca()

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x, y, z)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Surface Plot')

plt.show()

# %%
import seaborn as sns
sns.set()
